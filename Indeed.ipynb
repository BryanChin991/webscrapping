# %% [markdown]
# # Introduction
# <p>Indeed dataset </p>

# %%
import os
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Data Compilation

# %%
path = '/Users/Asus/Desktop/Unity Game/python/Data_Analysis/WebScrapping/Indeed/Scraping_lists'

df = pd.DataFrame()

for file in os.listdir(path):
    df = df.append(pd.read_csv(os.path.join(path, file)), ignore_index=True)

# %% [markdown]
# ### Checking data shape

# %%
print(f'Data shape: {df.shape}')
# Out:
# Data shape: (1169, 6)

# %%
# remove duplicate data
df = df.drop_duplicates()
# export dataset to csv file
df.to_csv(os.path.join(path, 'indeed_complete_dataset.csv'), index=False)

len(df.drop_duplicates())
# Out:
# 1020

# %%
df.head()
# Out:
#                                             Title  \
# 0                                  Data Scientist
# 1                                  Data Scientist
# 2  Data Analyst / Data Scientist (Work From Home)
# 3                                  Data Scientist
# 4                                  Data Scientist
#
#                       Company Name      Location  \
# 0              Shoppr Labs Sdn Bhd  Kuala Lumpur
# 1  Asia Pacific University Sdn Bhd  Kuala Lumpur
# 2            CPR Vision Management           NaN
# 3                           Scicom  Kuala Lumpur
# 4               VSure Tech Sdn Bhd  Kuala Lumpur
#
#                          Salary  Rating  \
# 0   RM 3,500 - RM 3,999 a month     NaN
# 1   RM 3,000 - RM 3,499 a month     NaN
# 2  RM 6,000 - RM 12,000 a month     NaN
# 3                           NaN     3.9
# 4                           NaN     NaN
#
#                                         Descriptions
# 0  Knowledge of big data technologies and machine...
# ...

# %% [markdown]
# ## Data Processing- Title

# %% [markdown]
# - To classify common job title into category below

# %%
df['Data Science'] = [1 if re.search('scien+', title.lower())!=None else 0 for title in df.Title]
df['Data Analyst'] = [1 if re.search('analy+', title.lower())!=None else 0 for title in df.Title]
df['Data Engineer'] = [1 if re.search('engineer+', title.lower())!=None else 0 for title in df.Title]
df['Data'] = [1 if re.search('data+', title.lower())!=None else 0 for title in df.Title]
df['Programmer'] = [1 if re.search('program+', title.lower())!=None else 0 for title in df.Title]
df['IT'] = [1 if re.search('it+', title.lower())!=None else 0 for title in df.Title]
df['Tester'] = [1 if re.search('test+', title.lower())!=None else 0 for title in df.Title]
df['Digital'] = [1 if re.search('digit+', title.lower())!=None else 0 for title in df.Title]

df['Project'] = [1 if re.search('project+', title.lower())!=None else 0 for title in df.Title]
df['Product'] = [1 if re.search('product+', title.lower())!=None else 0 for title in df.Title]
df['Research'] = [1 if re.search('research+', title.lower())!=None else 0 for title in df.Title]
df['Consultant'] = [1 if re.search('consult+', title.lower())!=None else 0 for title in df.Title]
df['Developer'] = [1 if re.search('develop+', title.lower())!=None else 0 for title in df.Title]
df['Support'] = [1 if re.search('support+', title.lower())!=None else 0 for title in df.Title]
df['Designer'] = [1 if re.search('design+', title.lower())!=None else 0 for title in df.Title]
df['Officer'] = [1 if re.search('office+', title.lower())!=None else 0 for title in df.Title]
df['Customer'] = [1 if re.search('customer+', title.lower())!=None else 0 for title in df.Title]
df['Quality'] = [1 if re.search('quality+', title.lower())!=None or re.search('qa+', title.lower())!=None else 0 for title in df.Title]
                  
df['Business'] = [1 if re.search('business+', title.lower())!=None else 0 for title in df.Title]
df['Sale'] = [1 if re.search('sale+', title.lower())!=None else 0 for title in df.Title]       
df['Marketing'] = [1 if re.search('market+', title.lower())!=None else 0 for title in df.Title]               
df['Finance'] = [1 if re.search('finance+', title.lower())!=None else 0 for title in df.Title]

df['Director'] = [1 if re.search('director+', title.lower())!=None else 0 for title in df.Title]
df['President'] = [1 if re.search('president+', title.lower())!=None else 0 for title in df.Title]
df['Management'] = [1 if re.search('manage+', title.lower())!=None else 0 for title in df.Title]
df['Head'] = [1 if re.search('head+', title.lower())!=None else 0 for title in df.Title]
df['Specialist'] = [1 if re.search('specialist+', title.lower())!=None else 0 for title in df.Title]
df['Associate'] = [1 if re.search('assoc+', title.lower())!=None else 0 for title in df.Title]
df['Expert'] = [1 if re.search('expert+', title.lower())!=None else 0 for title in df.Title]
df['Executive'] = [1 if re.search('execut+', title.lower())!=None else 0 for title in df.Title]
df['Senior'] = [1 if re.search('senior+', title.lower())!=None else 0 for title in df.Title]
df['Junior'] = [1 if re.search('junior+', title.lower())!=None else 0 for title in df.Title]
df['Intern'] = [1 if re.search('intern+', title.lower())!=None else 0 for title in df.Title]

# %% [markdown]
# - Some job title might have more than one category

# %%
job_data = ['Data Science', 'Data Analyst', 'Data Engineer', 'Data', 'IT', 'Programmer', 'Tester', 'Digital']
job_field = ['Project', 'Product', 'Research','Consultant','Developer', 'Support', 'Designer', 'Officer', 'Customer', 'Quality']
Job_sale = ['Business', 'Sale', 'Marketing', 'Finance']
job_level = ['Director', 'President', 'Management', 'Head', 'Specialist', 'Associate', 'Expert', 'Executive', 'Senior', 'Junior', 'Intern']

df['variety'] = df[[*job_data, *job_field, *Job_sale, *job_level]].sum(axis=1)
df[['Title', *job_data, *job_field, *Job_sale, *job_level, 'variety']].sort_values(by='variety', ascending=False).head()
# Out:
#                                                   Title  Data Science  \
# 362   Technology Consulting - Digital Analyst, Senio...             0
# 1161        Analyst- Digital Customer (Salesforce) - MY             0
# 778   Manager/ Senior Manager - Data Engineer, Data ...             0
# 806                    Senior Digital Marketing Analyst             0
# 266   Senior Associate - Data Engineer, Data & Analy...             0
#
#       Data Analyst  Data Engineer  Data  IT  Programmer  Tester  Digital  \
# 362              1              0     0   1           0       0        1
# 1161             1              0     0   1           0       0        1
# 778              1              1     1   0           0       0        0
# 806              1              0     0   1           0       0        1
# 266              1              1     1   0           0       0        0
#
#       Project  ...  Management  Head  Specialist  Associate  Expert  \
# ...

# %%
# for those did not have specific category yet
df[df[[*job_data, *job_field, *Job_sale, *job_level]].sum(axis=1) == 0][['Title', 'Descriptions']]
# Out:
#                              Title  \
# 171      MYS CTSM KL Authorization
# 175                  AVP, DM - SAS
# 228                       RPA Lead
# 231                     BSA Hybris
# 261    GTWB - Application Delivery
# 605   Seismic Imaging Geophysicist
# 634                     YOODO CLVM
# 994                       Creative
# 1135                    (Malaysia)
#
#                                            Descriptions
# 171   Identify inconsistencies in data or results, a...
# 175   Hands-on experience with integration of data f...
# 228   Candidate must possess excellent communication...
# 231   Collaborate with Business/IT in collecting fee...
# 261   Develop data design and conduct data testing. ...
# 605   With CGG’s Subsurface Imaging team, you will l...
# 634   Manage and execute various campaigns in a fast...
# 994   The long-term aim was to curate diverse young ...
# 1135  Propose and work with existing data models and...
